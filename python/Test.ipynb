# %%
# Workaround for OpenMP runtime error (libiomp5md.dll)
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %% [markdown]
# # Testing OpenCV Tool Tip Recognition

# %%
import cv2
import datetime
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO
from contextlib import redirect_stdout
import zipfile
import json
from pathlib import Path
import pandas as pd
import sys
sys.path.insert(0, '../src')
from src.tracker import track_lucas_kanade_optical_flow, calculate_statistics, plot_trajectory, export_review_zip

# %% [markdown]
# ### Importing Cataract 1k videos

# %%
# !pip install synapseclient
# !pip install synapseutils

# import synapseclient 
# import synapseutils 

# syn = synapseclient.Synapse() 
# syn.login(authToken="eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..tjXyKnQTHMNibnM_EpEhOZkPekVA1xQhFRR_ZZE7iEFEV6-RkDhan5wTmwB_fvVblU90EXE7zUIq0V7JHFI5zVXIZ2CjqROup-BjXCcPQXdddbFiFbyFDEa7FU1N92YyyYekMe9Qy3LWucUVLXYyLh0z-_41SopoJmjAwd4apcEoJB1d8NrrA-GRZL7gwr3ktuRh9wHFGvGuoUZSCBeWD0yl9dioRE_ifMZ81zIhIKbOLRvycXo2nnRjveZkzmbwHmGZNfdxHlV2tJbLyxrkc0ORjSjkLkCXK3cKZtuj6YTjO1-X6PRJk736kZd3nyWmTxRUNpm0CgygkKUS3pgy-g") 
# files = synapseutils.syncFromSynapse(syn, 'syn52540135') 

# Also using manual local path
videoFilePath = "C:\\Users\\timfk\\OneDrive\\QMUL MSc Robotics and AI\\Research Project\\Resources\\case_5309.mp4"

# %% [markdown]
# ### Motion Tracking with Lucas-Kanade Optical Flow [Copilot Generated]

# %%
# === STREAMLINED OPTICAL FLOW TRACKING + FULL EXPORT ===




try:
    # Track features in video using Lucas-Kanade
    tracked_frames, centers, frame_count, fps = track_lucas_kanade_optical_flow(
        videoFilePath, 
        max_seconds=30, 
        show_progress=True, 
        show_keyframes=True
    )
    
    # Calculate statistics
    stats = calculate_statistics(centers)
    
    # Plot results
    plot_trajectory(centers)
    
    # Export to ZIP
    export_review_zip(centers, tracked_frames, frame_count, fps, videoFilePath,  output_file= videoFilePath + "_" + datetime.now().strftime("%Y-%m-%d_%H-%M-%S") + "_review.zip") # type: ignore
    
except IOError as e:
    print(f"❌ Error: {e}")
# Out:
# ✅ Loaded: 512x384 @ 59.94005994005994fps → 1798 frames max
# Initial features: 100
# Frame 0
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 8
#       1 # === STREAMLINED OPTICAL FLOW TRACKING + FULL EXPORT ===
#       6 try:
#       7     # Track features in video using Lucas-Kanade
# ----> 8     tracked_frames, centers, frame_count, fps = track_lucas_kanade_optical_flow(
#       9         videoFilePath,
#      10         max_seconds=30,
#      11         show_progress=True,
#      12         show_keyframes=True
#      13     )
#      15     # Calculate statistics
#      16     stats = calculate_statistics(centers)
#
# File c:\Git\QMUL-Research-Project\python\src\tracker.py:389, in track_lucas_kanade_optical_flow(video_path, max_seconds, show_progress, show_keyframes)
#     376 """
# ...
